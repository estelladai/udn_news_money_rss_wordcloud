# %%
# !pip install wordcloud
# !pip install jieba
# !pip install lxml
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.10/site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: jieba in /opt/conda/lib/python3.10/site-packages (0.42.1)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (4.9.2)
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.10/site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import jieba
#指定使用繁體辭典
jieba.set_dictionary('jieba_data/dict.txt.big')

# %%
import requests
from bs4 import BeautifulSoup

#設定request header
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"
my_headers = {
    'User-Agent': user_agent,
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "accept-encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "cache-control": "no-cache",
    "Accept-Charset": "UTF8,utf-8;q=0.7,*;q=0.7"
}

# 爬取新聞網站標題和連結
url = "https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
items = soup.findAll("item")

i = 1
for item in items:
    title = item.title.text.strip()
    title_link = item.guid.text
    print("%s, %s, %s" % (i, title, title_link))
    i += 1
# Out:
# 1, 美企投資大陸限令 將啟動, https://money.udn.com/money/story/10511/7115236
# 2, 中國前駐美大使：美國想跟中國對話 不能只靠說, https://money.udn.com/money/story/10511/7115045
# 3, FT：美外洩機密文件稱 中國大陸正在打造劫持敵方衛星的網路武器, https://money.udn.com/money/story/10511/7114416
# 4, 紐時：習近平認接觸無成效 雙管齊下應對美國, https://money.udn.com/money/story/10511/7114315
# 5, 葉倫談美中 國安先於經濟, https://money.udn.com/money/story/10511/7112782
# 6, 葉倫談美中關係：國安優先於經濟, https://money.udn.com/money/story/10511/7111981
# 7, 美對陸出口限制 科林研發：沒擔心的那麼嚴, https://money.udn.com/money/story/10511/7111045
# 8, 違規賣硬碟給華為 希捷遭美國政府重罰93億元, https://money.udn.com/money/story/10511/7110369
# 9, 葉倫演講 聚焦美中競爭, https://money.udn.com/money/story/10511/7109700
# 10, 美國針對TikTok立法影響範圍太大 反遭科技公司抵制, https://money.udn.com/money/story/10511/7109534
# 11, 美國反制大陸影響力 官員：與夥伴付出相當大努力, https://money.udn.com/money/story/10511/7109437
# 12, 美眾院委員會將進行兵棋推演 模擬中共武力犯台, https://money.udn.com/money/story/10511/7108941
# 13, 中國在美設祕密警局  遍布舊金山與休士頓等大城, https://money.udn.com/money/story/10511/7108233
# 14, 布林肯：可推動美中關係  但北京須先表明意圖, https://money.udn.com/money/story/10511/7106721
# 15, TikTok禁令未明定執行方法 蒙大拿州落實有難度, https://money.udn.com/money/story/10511/7105643
# 16, 美制裁2家大陸企業  指涉供應芬太尼原料, https://money.udn.com/money/story/10511/7103256
# 17, 干預美國COVID-19溯源聽證會  中國抗議信曝光, https://money.udn.com/money/story/10511/7101286
# 18, 美國蒙大拿州開出第一槍 通過全面禁止下載TikTok, https://money.udn.com/money/story/10511/7100242
# 19, 美國制裁12企業指控助俄 中國斥長臂管轄, https://money.udn.com/money/story/10511/7099829
# /opt/conda/lib/python3.10/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
#爬取每則新聞內文
import requests
from bs4 import BeautifulSoup
from lxml import html
import random
import time

url = "https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
items = soup.findAll("item")

all_content = []
for item in items:
    title_link = item.guid.text
    print(title_link)
    content_response = requests.get(title_link)
    content_tree = html.fromstring(content_response.content)
    content = content_tree.xpath('//*[@id="article_body"]//p[not(@style)]')
    
    article_text = ""
    for p in content:
        article_text += p.text_content()
        
    all_content.append(article_text)
    
    sleep_time = random.randint(3, 10)
    print("sleep time: %s sec"%(sleep_time))
    time.sleep(sleep_time)

print(all_content)
# Out:
# https://money.udn.com/money/story/10511/7115236
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/7115045
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/7114416
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/7114315
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/7112782
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/7111981
# sleep time: 8 sec
# https://money.udn.com/money/story/10511/7111045
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/7110369
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/7109700
# sleep time: 5 sec
# https://money.udn.com/money/story/10511/7109534
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/7109437
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/7108941
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/7108233
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/7106721
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/7105643
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/7103256
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/7101286
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/7100242
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/7099829
# sleep time: 3 sec
# ['\r\n彭博資訊報導，美國總統拜登力求在未來幾周簽署行政命令，限制美企對中國大陸關鍵經濟領域的投資。拜登政府討論此措施近兩年，如今計劃在5月19日開幕的G7日本峰會前後行動。\r\n\r\n知情人士說，美國一直向G7夥伴簡報擬採取的高科技業投資限制措施，並希望在下月峰會上獲得各方背書，即使其他國家預料不會同時宣布類似措施。其中一位知情人士說，最有可能的順序是，在盟友表達支持後，拜登很快簽署行政命令。\r\n\r\n此舉代表美國對大陸的經濟戰進入新階段：前美國總統川普對中國進口商品加徵關稅，拜登近來不斷加大對美國關鍵技術出口的限制，接下來華府目標將放在兩國之間的資本流動。\r\n\r\n報導指出，擬議中的行政命令將涵蓋半導體、人工智慧（AI）和量子運算等，聚焦美企在管理上發揮積極作用的投資領域。受限的包括風險投資和私募股權，以及特定形式的技術轉讓和合資企業。涉及起草行政命令的官員表示，目標是潛在的新投資，而非現有投資。\r\n\r\n某些類型的投資將完全禁止，其它類型則將要求企業通報美國政府。有關細節將在行政命令發布後的一系列法規中闡述。美國官員表示，投資限制打算扼殺可能提升中國軍力的關鍵融資和技術。', '中國迄今拒絕美國提議高層對話，中國前駐美大使崔天凱今天以台灣為例，批評美方說一套、做一套，何以取信於人。他說，「對話如果沒有誠意，不能平等相待，也不見得能解決問題」。\n崔天凱21日出席在上海舉辦的「中國式現代化與世界」藍廳論壇，期間接受官媒央視博主「玉淵譚天」專訪談近期陷入歷史低位的中美關係。\n當被問及中國學者鄭永年近日提到，「中美關係很重要，但對中美雙方來說，並不是唯一的外交關係」，崔天凱說，中國、美國這兩個這麼大的國家，作為世界前兩大經濟體，兩國還都是聯合國安理會常任理事國，在世界上也有各自的重要性。這兩個國家之間按理說應該有更多的交往，包括政府之間的交往，包括高層的交往，這種交往應該是相當頻繁的，相當經常的，「但是現在很難做到這一點」。\n崔天凱認為這主要有兩個問題：\n第一個就是「能不能真正做到相互尊重」。兩個國家之間交往跟兩個人之間交往一樣，如果不是平等相待，相互尊重，怎麼交往下去？但是美國有些人，他的習慣思維就是說我要強勢來對付你，言下之意他是強勢，就要把對方打成弱勢。用他們的話說就是要從實力地位出發來和你交往，老是這種心態，不能平等相待，不能尊重對方，怎麼交往？\n他說，中國有句古話叫「智者不惑，仁者不憂，勇者不懼」。你要是智者、仁者、勇者，你不需要每天把實力掛在嘴上，這麼說可能正是心裡沒底的表現。「我覺得這是影響中美交往，包括高層交往一個很重要的原因。」\n第二個，就是「能不能做到言而有信」。崔天凱說，現在經常看到這樣的現象，中美之間有一次正式的交往，甚至相當高層級的交往，然後美國表態好像也還可以，講了幾個不，幾個無意，回過頭去馬上就提升跟台灣的官方關係，馬上就繼續賣武器給台灣，甚至幫台灣在國際上去搞什麼國際空間，然後抹黑中國，然後是脫鉤斷鏈，制裁中國企業，就幹一系列的事情。\n「你說的一套做的一套，何以取信於人？」崔天凱反問，如果官方的高層溝通會晤，你說的話不能取信於人，這些交往還有什麼意義？他覺得這兩個問題如果不解決，會繼續影響中美之間的交流。\n針對美國最近一直在釋放希望對話的信號，崔天凱則說：「不對話肯定解決不了問題。對話如果沒有誠意，不能平等相待，也不見得能解決問題。」\n崔天凱表示，原來美國人很喜歡說一句話，他嫌中美之間對話多了，他說「我們不能為了對話而對話」。現在回過頭來看，中國也可以跟他說同樣的話：「你如果沒有誠意，沒有一個平等相待的態度，那光為了對話而對話也沒有多大意義」。', '金融時報21日獨家披露，一分外洩的美國情資報告指出，中國大陸正在打造先進的網路武器，以「奪取敵方衛星的控制權」，讓這些衛星在戰時變成無法用於數據信號或監控。\r\n\r\n這分有著中央情報局（CIA）註記的文件據稱是美國空中國民兵成員特薛拉（Jack Teixeira）分享出去的數十分文件之一，發表時間是在今年，此前未曾有媒體報導過。\r\n\r\n根據報導，美方評估認為陸方推動發展「拒止、利用或劫持」（deny, exploit or hijack）敵方衛星的能力是控制資訊此一目標的核心內容，並指北京當局認為這是一個關鍵的「作戰領域」。\r\n\r\n這種攻擊方式最初在1980年代開發，試圖藉由「Tirada-2」等車載干擾系統在類似頻率進行廣播，進而蓋過SpaceX低地軌道衛星跟地面終端機之間的訊號。中國大陸更具雄心的網路攻擊目標則是模仿敵方衛星從操作人員接收的訊號，在戰鬥的關鍵時刻期間欺騙衛星被完全接管或發生故障。\r\n\r\n據報導，這種性質的網路能力將遠遠超過俄羅斯已經在烏克蘭部署的任何設備。美方機密文件指出，這種網路能力將會讓陸方「奪取衛星的控制權，讓其變成無法有效支持通信、武器或情報、監控與偵察系統」。美國從未揭露他們是否具有類似的能力。白宮國安會、CIA與國防部拒絕置評，中國大陸政府沒有立刻評論此事。\r\n', '紐約時報今天報導，中國領導人習近平近期藉熱情招待多國元首，藉此向華盛頓表達強硬立場，另方面又展示與全球做生意的積極態度，這種雙管齊下的做法凸顯北京認為中美接觸並無成效。\n習近平上週為巴西總統魯拉（Luiz Inácio Lula daSilva）鋪開了紅地毯，稱讚魯拉是「中國人民的老朋友」。他也與法國總統馬克宏（EmmanuelMacron）在花園裡喝茶；還與沙烏地阿拉伯王儲穆罕默德通電話，表達對穆斯林齋月的良好祝願。\n據報導，但在習近平最近幾週熱情招呼這些國家和其他世界領導人的時候，美國得到的卻只是冷落。中國拒絕了拜登政府重啟高層會談、緩和台灣緊張局勢的嘗試。習近平政府還加劇了嘲諷和批評美國和西方民主制度的運動。\n中國這些公開批評美國、同時加強與美國盟友關係的努力反映了北京想展示的強硬立場；顯示中美關係已跌到了幾十年來的最低點。\n報導指出，中國一方面正在試圖把握分寸，在外交上冷落美國，另一方面則試圖讓各國央行和投資者相信，在實行了多年遏制COVID-19疫情的嚴厲措施後，中國再次向世界開放。\n例如上週，中國央行行長易綱與美國聯準會主席鮑爾（Jerome Powell）舉行會晤，討論了兩國經濟；財政部長葉倫（Janet Yellen）和商務部長雷蒙多（GinaRaimondo）也正在計劃訪問中國。\n報導引述一些分析人士稱，中國這種雙管齊下的做法證明，習近平已完全接受了中美接觸並無成效的觀點，至少目前如此。而這讓人們更加擔心這兩個大國正朝著可能發生碰撞的方向移動，並可能會導致危險的事件，甚至圍繞台灣和其他地緣政治熱點問題發生戰爭。\n美國智庫「捍衛民主基金會」（Foundation forDefense of Democracies）學者辛格頓（CraigSingleton）說，「習近平顯然認為，為接觸而接觸是徒勞無益的事情。對話的時間已經過去。現在反而是北京做好迎接困難的準備的時候」。\n而研究中國政治的克萊蒙特麥肯納學院教授裴敏欣表示，中國政府可能會在覺得自己有了更多籌碼的時候重新與華盛頓接觸。但它可能會首先去加深與更多不結盟國家（如巴西）的關係，或者讓歐洲國家在是否緊密跟隨美國對中強硬立場的問題上產生更大的分歧。\n上海復旦大學國際關係學院院長吳心伯表示，習近平和拜登去年11月在印尼會晤後取得的適度進展在氣球事件和蔡英文過境美國後幾乎消失殆盡，「中國認為美國既沒有誠意也沒有能力改善關係。」', '\r\n美國財政部長葉倫談到美中關係時表示，解決國家安全問題將優先於維持經濟成長。\r\n\r\n葉倫預定20日上午在華盛頓的約翰霍普金斯大學高等國際關係學院發表演說，她在預備演講稿中列出美中關係三大目標：保護人權和國家安全、建立健康的經濟關係，以及在重大全球議題上合作。\r\n\r\n她批評北京政府為其國內工業提供補貼，並表示美國仍將是世界上占主導地位的經濟強權。\r\n\r\n美國總統拜登政府正在推動重新調整美國經濟及其盟友的經濟方向，使其遠離中國。西方官員憂慮在電動車電池等礦物原料方面太依賴中國，並且擔心北京可能會在衝突中切斷這些原料供應。\r\n\r\n美國還準備限制私募股權和創投業者在中國的投資，限制重點放在會幫助共軍的科技。美國去年已禁止對中國出口一些先進半導體和晶片製造設備。\r\n\r\n葉倫在預備講稿中說：「即使這些政策可能產生經濟衝擊，但它們是由直接的國家安全考慮驅動。」「我們不會在這些問題妥協，即使它們迫使我們與經濟利益做權衡。」\r\n\r\n葉倫說，美國仍可以在經濟上與中國競爭。她在預備講稿中說：「一個按照國際規則行事的成長中中國，對美國和世界都有好處。（美中）兩國都可以從經濟領域良性競爭中受惠。」「但健康的經濟競爭（雙方都受惠）只有在競爭是公平的情況下才能持續下去。」\r\n\r\n雖然葉倫經常在公開談話中批評中國，但這位聯準會前主席在這份講稿中展現更強硬的語氣。相較拜登政府的其他官員，葉倫之前的說法聽起來較願意在經濟問題上與中國合作，例如呼籲取消對中國進口商品課徵的部分關稅，但其他官員想要保持關稅不變。熟悉她想法的人士表示，她擔心如果北京認為拜登政府的政策過於具懲罰性，中國可能會對美國進行報復。\r\n\r\n拜登政府對中國的態度引發一些外國官員的憂慮，他們擔心世界經濟可能分裂成相互較勁的集團，一個由美國主導，另一個由中國主導，從而減緩全球貿易和投資。國際貨幣基金（IMF）一再警告勿使經濟碎片化。歐洲央行總裁拉加德日前表示，政策制定者需採取措施以確保地緣政治緊張 ...

# %%
import re

re_all_content = []
for content in all_content:
    re_all_content.append(re.sub(r'\r\n|\n', '', content))

re_all_content_string = ''.join(re_all_content)
print(re_all_content_string)
# Out:
# 彭博資訊報導，美國總統拜登力求在未來幾周簽署行政命令，限制美企對中國大陸關鍵經濟領域的投資。拜登政府討論此措施近兩年，如今計劃在5月19日開幕的G7日本峰會前後行動。知情人士說，美國一直向G7夥伴簡報擬採取的高科技業投資限制措施，並希望在下月峰會上獲得各方背書，即使其他國家預料不會同時宣布類似措施。其中一位知情人士說，最有可能的順序是，在盟友表達支持後，拜登很快簽署行政命令。此舉代表美國對大陸的經濟戰進入新階段：前美國總統川普對中國進口商品加徵關稅，拜登近來不斷加大對美國關鍵技術出口的限制，接下來華府目標將放在兩國之間的資本流動。報導指出，擬議中的行政命令將涵蓋半導體、人工智慧（AI）和量子運算等，聚焦美企在管理上發揮積極作用的投資領域。受限的包括風險投資和私募股權，以及特定形式的技術轉讓和合資企業。涉及起草行政命令的官員表示，目標是潛在的新投資，而非現有投資。某些類型的投資將完全禁止，其它類型則將要求企業通報美國政府。有關細節將在行政命令發布後的一系列法規中闡述。美國官員表示，投資限制打算扼殺可能提升中國軍力的關鍵融資和技術。中國迄今拒絕美國提議高層對話，中國前駐美大使崔天凱今天以台灣為例，批評美方說一套、做一套，何以取信於人。他說，「對話如果沒有誠意，不能平等相待，也不見得能解決問題」。崔天凱21日出席在上海舉辦的「中國式現代化與世界」藍廳論壇，期間接受官媒央視博主「玉淵譚天」專訪談近期陷入歷史低位的中美關係。當被問及中國學者鄭永年近日提到，「中美關係很重要，但對中美雙方來說，並不是唯一的外交關係」，崔天凱說，中國、美國這兩個這麼大的國家，作為世界前兩大經濟體，兩國還都是聯合國安理會常任理事國，在世界上也有各自的重要性。這兩個國家之間按理說應該有更多的交往，包括政府之間的交往，包括高層的交往，這種交往應該是相當頻繁的，相當經常的，「但是現在很難做到這一點」。崔天凱認為這主要有兩個問題：第一個就是「能不能真正做到相互尊重」。兩個國家之間交往跟兩個人之間交往一樣，如果不是平等相待，相互尊重，怎麼交往下去？但是美國有些人，他的習慣思維就是說我要強勢來對付你，言下之意他是強勢，就要把對方打成弱勢。用他們的話說就是要從實力地位出發來和你交往，老是這種心態，不能平等相待，不能尊重對方，怎麼交往？他說，中國有句古話叫「智者不惑，仁者不憂，勇者不懼」。你要是智者、仁者、勇者，你不需要每天把實力掛在嘴上，這麼說可能正是心裡沒底的表現。「我覺得這是影響中美交往，包括高層交往一個很重要的原因。」第二個，就是「能不能做到言而有信」。崔天凱說，現在經常看到這樣的現象，中美之間有一次正式的交往，甚至相當高層級的交往，然後美國表態好像也還可以，講了幾個不，幾個無意，回過頭去馬上就提升跟台灣的官方關係，馬上就繼續賣武器給台灣，甚至幫台灣在國際上去搞什麼國際空間，然後抹黑中國，然後是脫鉤斷鏈，制裁中國企業，就幹一系列的事情。「你說的一套做的一套，何以取信於人？」崔天凱反問，如果官方的高層溝通會晤，你說的話不能取信於人，這些交往還有什麼意義？他覺得這兩個問題如果不解決，會繼續影響中美之間的交流。針對美國最近一直在釋放希望對話的信號，崔天凱則說：「不對話肯定解決不了問題。對話如果沒有誠意，不能平等相待，也不見得能解決問題。」崔天凱表示，原來美國人很喜歡說一句話，他嫌中美之間對話多了，他說「我們不能為了對話而對話」。現在回過頭來看，中國也可以跟他說同樣的話：「你如果沒有誠意，沒有一個平等相待的態度，那光為了對話而對話也沒有多大意義」。金融時報21日獨家披露，一分外洩的美國情資報告指出，中國大陸正在打造先進的網路武器，以「奪取敵方衛星的控制權」，讓這些衛星在戰時變成無法用於數據信號或監控。這分有著中央情報局（CIA）註記的文件據稱是美國空中國民兵成員特薛拉（Jack Teixeira）分享出去的數十分文件之一，發表時間是在今年，此前未曾有媒體報導過。根據報導，美方評估認為陸方推動發展「拒止、利用或劫持」（deny, exploit or hijack）敵方衛星的能力是控制資訊此一目標的核心內容，並指北京當局認為這是一個關鍵的「作戰領域」。這種攻擊方式最初在1980年代開發，試圖藉由「Tirada-2」等車載干擾系統在類似頻率進行廣播，進而蓋過SpaceX低地軌道衛星跟地面終端機之間的訊號。中國大陸更具雄心的網路攻擊目標則是模仿敵方衛星從操作人員接收的訊號，在戰鬥的關鍵時刻期間欺騙衛星被完全接管或發生故障。據報導，這種性質的網路能力將遠遠超過俄羅斯已經在烏克蘭部署的任何設備。美方機密文件指出，這種網路能力將會讓陸方「奪取衛星的控制權，讓其變成無法有效支持通信、武器或情報、監控與偵察系統」。美國從未揭露他們是否具有類似的能力。白宮國安會、CIA與國防部拒絕置評，中國大陸政府沒有立刻評論此事。紐約時報今天報導，中國領導人習近平近期藉熱情招待多國元首，藉此向華盛頓表達強硬立場，另方面又展示與全球做生意的積極態度，這種雙管齊下的做法凸顯北京認為中美接觸並無成效。習近平上週為巴西總統魯拉（Luiz Inácio Lula daSilva）鋪開了紅地毯，稱讚魯拉是「中國人民的老朋友」。他也與法國總統馬克宏（EmmanuelMacron）在花園裡喝茶；還與沙烏地阿拉伯王儲穆罕默德通電話，表達對穆斯林齋月的良好祝願。據報導，但在習近平最近幾週熱情招呼這些國家和其他世界領導人的時候，美國得到的卻只是冷落。中國拒絕了拜登政府重啟高層會談、緩和台灣緊張局勢的嘗試。習近平政府還加劇了嘲諷和批評美國和西方民主制度的運動。中國這些公開批評美國、同時加強與美國盟友關係的努力反映了北京想展示的強硬立場；顯示中美關係已跌到了幾十年來的最低點。報導指出，中國一方面正在試圖把握分寸，在外交上冷落美國，另一方面則試圖讓各國央行和投資者相信，在實行了多年遏制COVID-19疫情的嚴厲措施後，中國再次向世界開放。例如上週，中國央行行長易綱與美國聯準會主席鮑爾（Jerome Powell）舉行會晤，討論了兩國經濟；財政部長葉倫（Janet Yellen）和商務部長雷蒙多（GinaRaimondo）也正在計劃訪問中國。報導引述一些分析人士稱，中國這種雙管齊下的做法證明，習近平已完全接受了中美接觸並無成效的觀點，至少目前如此。而這讓人們更加擔心這兩個大國正朝著可能發生碰撞的方向移動，並可能會導致危險的事件，甚至圍繞台灣和其他地緣政治熱點問題發生戰爭。美國智庫「捍衛民主基金會」（Foundation forDefense of Democracies）學者辛格頓（CraigSingleton）說，「習近平顯然認為，為接觸而接觸是徒勞無益的事情。對話的時間已經過去。現在反而是北京做好迎接困難的準備的時候」。而研究中國政治的克萊蒙特麥肯納學院教授裴敏欣表示，中國政府可能會在覺得自己有了更多籌碼的時候重新與華盛頓接觸。但它可能會首先去加深與更多不結盟國家（如巴西）的關係，或者讓歐洲國家在是否緊密跟隨美國對中強硬立場的問題上產生更大的分歧。上海復旦大學國際關係學院院長吳心伯表示，習近平和拜登去年11月在印尼會晤後取得的適度進展在氣球事件和蔡英文過境美國後幾乎消失殆盡，「中國認為美國既沒有誠意也沒有能力改善關係。」美國財政部長葉倫談到美中關係時表示，解決國家安全問題將優先於維持經濟成長。葉倫預定20日上午在華盛頓的約翰霍普金斯大學高等國際關係學院發表演說，她在預備演講稿中列出美中關係三大目標：保護人權和國家安全、建立健康的經濟關係，以及在重大全球議題上合作。她批評北京政府為其國內工業提供補貼，並表示美國仍將是世界上占主導地位的經濟強權。美國總統拜登政府正在推動重新調整美國經濟及其盟友的經濟方向，使其遠離中國。西方官員憂慮在電動車電池等礦物原料方面太依賴中國，並且擔心北京可能會在衝突中切斷這些原料供應。美國還準備限制私募股權和創投業者在中國的投資，限制重點放在會幫助共軍的科技。美國去年已禁止對中國出口一些先進半導體和晶片製造設備。葉倫在預備講稿中說：「即使這些政策可能產生經濟衝擊，但它們是由直接的國家安全考慮驅動。」「我們不會在這些問題妥協，即使它們迫使我們與經濟利益做權衡。」葉倫說，美國仍可以在經濟上與中國競爭。她在預備講稿中說：「一個按照國際規則行事的成長中中國，對美國和世界都有好處。（美中）兩國都可以從經濟領域良性競爭中受惠。」「但健康的經濟競爭（雙方都受惠）只有在競爭是公平的情況下才能持續下去。」雖然葉倫經常在公開談話中批評中國，但這位聯準會前主席在這份講稿中展現更強硬的語氣。相較拜登政府的其他官員，葉倫之前的說法聽起來較願意在經濟問題上與中國合作，例如呼籲取消對中國進口商品課徵的部分關稅，但其他官員想要保持關稅不變。熟悉她想法的人士表示，她擔心如果北京認為拜登政府的政策過於具懲罰性，中國可能會對美國進行報復。拜登政府對中國的態度引發一些外國官員的憂慮，他們擔心世界經濟可能分裂成相互較勁的集團，一個由美國主導，另一個由中國主導，從而減緩全球貿易和投資。國際貨幣基金（IMF）一再警告勿使經濟碎片化。歐洲央行總裁拉加德日前表示，政策制定者需採取措施以確保地緣政治緊張不會加劇通膨。延伸閱讀Fed：美成長停滯 授信管道限縮美國財政部長葉倫在談到美中關係時表示，解決國家安全問題將優先於維持經濟成長。葉倫預定20日上午在華盛頓的約翰霍普金斯大學高等國際關係學院發表演說，她在預備演講稿中列出了美中關係的三大目標：保護人權和國家安全、建立健康的經濟關係，以及在重大全球問題上合作。 她批評北京政府為其國內工業提供補貼，並表示美國仍將是世界上占主導地位的經濟強權 ...

# %%
import jieba

# 準備停用詞庫
with open(file='jieba_data/stop_words.txt', mode='r', encoding='utf-8') as file:
    stop_words = file.read().split('\n')

# 使用jieba進行分詞
seg_words_list = jieba.lcut(re_all_content_string)
    
# 過濾停用詞
seg_stop_words_list = [term for term in seg_words_list if term not in stop_words]

print(seg_stop_words_list)
# Out:
# Building prefix dict from /home/jovyan/work/jieba_data/dict.txt.big ...
# Loading model from cache /tmp/jieba.ud3c40470d3518910bfd0dc86d865fad4.cache
# Loading model cost 0.818 seconds.
# Prefix dict has been built successfully.
# ['彭博', '資訊', '報導', '美國', '總統', '拜登', '力求', '未來', '幾周', '簽署', '行政命令', '限制', '美企對', '中國', '大陸', '關鍵', '經濟', '領域', '投資', '拜登', '政府', '討論', '此', '措施', '近兩年', '如今', '計劃', '5', '19', '開幕', 'G7', '日本', '峰會', '前後', '行動', '知情', '美國', '一直', 'G7', '夥伴', '簡報', '擬', '採取', '高科技', '業', '投資', '限制', '措施', '希望', '下', '月峰', '會上', '獲得', '各方', '背書', '國家', '預料', '不會', '同時', '宣布', '類似', '措施', '一位', '知情', '最有', '順序', '盟友', '表達', '支持', '拜登', '很快', '簽署', '行政命令', '此舉', '代表', '美國', '大陸', '經濟', '戰', '進入', '階段', '：', '前', '美國', '總統', '川普對', '中國', '進口商品', '加徵', '關稅', '拜登', '近來', '不斷', '加大', '美國', '關鍵技術', '出口', '限制', '接下來', '華府', '目標', '放在', '兩國之間', '資本', '流動', '報導', '擬議', '行政命令', '涵蓋', '半導體', '人工智慧', 'AI', '量子', '運算', '聚焦', '美企在', '管理', '發揮', '積極', '作用', '投資', '領域', '受限', '風險投資', '私募', '股權', '特定', '形式', '技術轉讓', '合資企業', '涉及', '起草', '行政命令', '官員', '目標', '潛在', '投資', '非', '現有', '投資', '某些', '類型', '投資', '完全', '禁止', '其它', '類型', '則', '將要', '求', '企業', '通報', '美國政府', '有關', '細節', '將在', '行政命令', '發布', '一系列', '法規', '闡述', '美國', '官員', '投資', '限制', '打算', '扼殺', '提升', '中國軍力', '關鍵', '融資', '技術', '中國', '迄今', '拒絕', '美國', '提議', '高層', '對話', '中國', '前', '駐', '美', '大使', '崔天凱', '今天', '以台灣', '為例', '批評', '美方', '一套', '做一套', '何以', '取信於人', '對話', '誠意', '不能', '平等', '相待', '不見得', '能', '解決問題', '崔天凱', '21', '出席', '上海', '舉辦', '中國式', '現代化', '世界', '藍廳', '論壇', '期間', '接受', '官媒', '央視', '博主', '玉淵', '譚天', '專訪', '談', '近期', '陷入', '歷史', '低位', '中美關係', '當被', '問及', '中國', '學者', '鄭', '永年', '近日', '提到', '中美關係', '很', '重要', '中美', '雙方', '來說', '不是', '唯一', '外交關係', '崔天凱', '中國', '美國', '這', '這麼', '國家', '作為', '世界', '前', '兩大', '經濟體', '兩國', '還都', '聯合國', '安理會常任理事國', '在世界上', '各自', '重要性', '這', '國家', '按理說', '應該', '交往', '政府', '交往', '高層', '交往', '交往', '應該', '頻繁', '經常', '但是', '很難', '做到', '這', '一點', '崔天凱', '這', '主要', '問題', '：', '第一個', '能', '不能', '真正', '做到', '相互尊重', '國家', '交往', '跟', '交往', '一樣', '不是', '平等', '相待', '相互尊重', '怎麼', '交往', '下去', '但是', '美國', '有些', '習慣', '思維', '就是說', '我要', '強勢', '來', '對付', '言下之意', '強勢', '就要', '把', '對方', '打成', '弱勢', '用', '的話', '要', '從實', '力', '地位', '出', '發來', '交往', '老是', '心態', '不能', '平等', '相待', '不能', '尊重', '對方', '怎麼', '交往', '中國', '有句', '古話', '叫', '智者', '不惑', '仁者', '不憂', '勇者不懼', '要是', '智者', '仁者', '勇者', '需要', '每天', '把', '實力', '掛在', '嘴', '這麼', '正是', '心裡', '沒底', '表現', '覺得', '這是', '影響', '美', '交往', '高層', '交往', '很', '重要', '原因', '第二個', '能', '不能', '做到', '言而有信', '崔天凱', '經常', '看到', '這樣', '現象', '美', '一次', '正式', '交往', '甚至', '高層', '級', '交往', '然後', '美國', '表態', '好像', '也還', '講了', '幾個', '幾個', '無意', '回過', '頭去', '馬上', '提升', '跟', '台灣', '官方', '關係', '馬上', '賣', '武器', '給台灣', '甚至', '幫台灣', '國際', '上去', '搞', '什麼', '國際', '空間', '然後', '抹黑', '中國', '然後', '脫鉤', '斷鏈', '制裁', '中國', '企業', '幹', '一系列', '事情', '一套', '做', '一套', '何以', '取信於人', '崔天凱', '反問', '官方', '高層', '溝通', '會晤', '的話', '不能', '取信於人', '交往', '還有', '什麼', '意義', '覺得', '這', '問題', '解決', '影響', '美', '交流', '美國', '最近', '一直', '釋放', '希望', '對話', '信號', '崔天凱', '則說', '：', '對話', '肯定', '解決不了', '問題', '對話', '誠意', '不能', '平等', '相待', '不見得', '能', '解決問題', '崔天凱', '原來', '美國', '很', '喜歡', '一句', '話', '嫌', '中美', '對話', '不能', '對話', '對話', '回過頭來', '看', '中國', '跟', '同樣', '的話', '：', '誠意', '平等', '相待', '態度', '那光', '對話', '對話', '多大', '意義', '金融時報', '21', '獨家', '披露', '一', '分外', '洩', '美國', '情資', '報告', '中國', '大陸', '打造', '先進', '網路', '武器', '奪取', '敵方', '衛星', '控制權', '衛星', '戰時', '變成', '無法', '用於', '數據信號', '監控', '這分', '著', '中央', '情報局', 'CIA', '註', '記', '文件', '據稱', '美國', '空中', '國民兵', '成員', '特薛拉', 'Jack', ' ', 'Teixeira', '分享', '出去', '數十', '分', '文件', '之一', '發表', '時間', '今年', '此前', '未曾', '媒體', '報導', '過', '根據', '報導', '美方', '評估', '陸方', '推動', '發展', '拒止', '利用', '劫持', 'deny', ' ', 'exploit', ' ', ' ', 'hijack', '敵方', '衛星', '能力', '控制', '資訊', '此一', '目標', '核心內容', '並指', '北京', '當局', '這是', '關鍵', '作戰', '領域', '攻擊方式', '最初', '1980', '年代', '開發', '試圖', '藉由', 'Tirada', '-', '2', '車載', '干擾', '系統', '類似', '頻率', '廣播', '進而', '蓋過', 'SpaceX', '低地', '軌道', '衛星', '跟', '地面', '終端機', '訊號', '中國', '大陸', '更具', '雄心', '網路', '攻擊', '目標', '則是', '模仿', '敵方', '衛星', '從', '操作', '人員', '接收', '訊號', '戰鬥', '關鍵時刻', '期間', '欺騙', '衛星', '完全', '接管', '發生', '故障', '據', '報導', '性質', '網路', '能力', '遠遠', '超過', '俄羅 ...

# %%
# 清除 matplotlib 快取
import matplotlib
print(matplotlib.get_configdir())
# !ls -la /home/jovyan/.config/matplotlib
# !rm -rf /home/jovyan/.cache/matplotlib
# Out:
# /home/jovyan/.config/matplotlib
# total 8
# drwsrwsr-x 2 jovyan users 4096 Apr 17 11:25 .
# drwsrwsr-x 3 jovyan users 4096 Apr 17 11:25 ..

# %%
# 繪製文字雲 by generate
from wordcloud import WordCloud
import matplotlib.pyplot as plt

seg_words = ' '.join(seg_stop_words_list)
wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate(seg_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# 繪製文字雲 by generate_from_frequencies
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

seg_stop_counter = Counter(seg_stop_words_list)

wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate_from_frequencies(seg_stop_counter)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('udn_news_wc.png', dpi=300)
plt.show()
